# %% [markdown]
# # Setup

# %% [markdown]
# 기본적으로 quantization을 적용하고 있어 GPU instance로 접근해야 합니다.

# %%
# !git clone https://github.com/yjkim-stat/LangDec.git
# Out:
# Cloning into 'LangDec'...
# remote: Enumerating objects: 63, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 63 (delta 28), reused 50 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (63/63), 64.68 KiB | 279.00 KiB/s, done.
# Resolving deltas: 100% (28/28), done.

# %%
# !pip3 install torch torchvision torchaudio

# %%
# !pip install -r LangDec/requirements.txt # clone 경로에 맞춰 설정

# %% [markdown]
# # Run scripts

# %% [markdown]
# 결과 저장을 위해 drive mount 이후 진행

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive
# !pwd

# %% [markdown]
# 실행하기 전에 해당 스크립트 파일을 열어서 환경변수 HF_TOKEN을 설정해야 합니다.

# %%
# !bash ./LangDec/scripts/run_sc-colab.sh
